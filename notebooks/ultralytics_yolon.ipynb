# %% [markdown]
# # Ultralytics
#
# Usig ultralytics library, try to detect a football match

# %%
# Install required packages in the current kernel
# %pip install -q ultralytics opencv-python matplotlib torch
